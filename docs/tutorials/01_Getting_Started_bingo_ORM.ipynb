# %% [markdown]
# # Getting Started with MolAlchemy Bingo - SQLAlchemy ORM
#
# This tutorial demonstrates how to use MolAlchemy with the Bingo PostgreSQL cartridge to perform chemical informatics operations using SQLAlchemy ORM. You'll learn how to:
#
# - Set up a PostgreSQL database with Bingo extension
# - Define SQLAlchemy models with chemical data types
# - Store and query molecular structures
# - Perform substructure searches
# - Calculate molecular fingerprints and similarity scores
#
# SQLAlchemy ORM provides a high-level, Pythonic interface for interacting with databases, while MolAlchemy extends this functionality to handle chemical data types and operations seamlessly using the powerful Bingo cartridge.
#
# ## Prerequisites
#
# Before starting this tutorial, make sure you have:
# - A PostgreSQL database with Bingo extension installed
# - MolAlchemy installed
# - A running PostgreSQL instance (you can use the provided Docker setup)
#
# The Bingo cartridge provides fast and efficient chemical search capabilities including exact structure search, substructure search, and similarity search with various fingerprint algorithms.

# %% [markdown]
# ## Setting Up the Database
# To set up a PostgreSQL database with the Bingo extension, use `ghcr.io/asiomchen/bingo-postgres:postgres17-bingo1.44.0` from [GitHub Container Registry](https://github.com/asiomchen/bingo-postgres/pkgs/container/bingo-postgres).
#
# ```sh
# docker run -d \
#   --name molalchemy-tutorial-bingo-orm \
#   -e POSTGRES_PASSWORD=example \
#   -e POSTGRES_DB=postgres \
#   -p 5432:5432 \
#   ghcr.io/asiomchen/bingo-postgres:postgres17-bingo1.44.0
# ```

# %% [markdown]
# ## Database Setup and Connection
#
# First, let's establish a connection to PostgreSQL and ensure the Bingo extension is enabled. We'll import the necessary modules from MolAlchemy and SQLAlchemy, then create a database engine and session.

# %%
import os

from sqlalchemy import (
    Boolean,
    Integer,
    String,
    engine,
    select,
    text,
)
from sqlalchemy.orm import (
    DeclarativeBase,
    Mapped,
    MappedAsDataclass,
    mapped_column,
    sessionmaker,
)

from molalchemy.bingo import functions, index, types

eng = engine.create_engine(
    os.environ.get(
        "BINGO_DATABASE_URL",
        "postgresql+psycopg://postgres:postgres@127.0.0.1:55432/postgres",
    )
)
SessionLocal = sessionmaker(autocommit=False, autoflush=False, bind=eng)
with SessionLocal() as session:
    print(session.execute(select(functions.getversion())).all())
# Out:
# [('1.44.0',)]

# %% [markdown]
# ## Defining a Molecule Model with Bingo
#
# Now let's create a SQLAlchemy model to store molecular data. The model uses:
#
# - `molalchemy.bingo.types.BingoMol` for storing molecular structures
# - `molalchemy.bingo.index.BingoMolIndex` to create a Bingo index for efficient chemical searches
# - Standard SQLAlchemy columns for metadata like name and properties
#
# The `bingo_idx` index on the `mol` column enables fast substructure and similarity searches using Bingo's optimized algorithms.

# %%
class Base(MappedAsDataclass, DeclarativeBase):
    pass


class Molecule(Base):
    __tablename__ = "molalchemy_tutorial_molecules"
    __table_args__ = (
        index.BingoMolIndex("molalchemy_tutorial_bingo_orm_mol_gist_idx", "mol"),
    )
    id: Mapped[int] = mapped_column(
        Integer, primary_key=True, autoincrement=True, init=False
    )
    name: Mapped[str] = mapped_column(String(100), unique=True)
    mol: Mapped[bytes] = mapped_column(types.BingoMol)
    is_nsaid: Mapped[bool] = mapped_column(Boolean, default=False)


Molecule.__table__.drop(eng, checkfirst=True)
Molecule.metadata.create_all(eng, checkfirst=False)

# %% [markdown]
# ### Useful index options
#
# Bingo index classes accept the standard keyword options supported by SQLAlchemy's `Index`. The most useful PostgreSQL options are:
#
# - `postgresql_where` creates a smaller partial index for rows that match a predicate. Queries must use a compatible predicate for PostgreSQL to choose that index.
# - `postgresql_concurrently=True` avoids blocking writes while an index is built. PostgreSQL requires this DDL to run in autocommit mode, outside a transaction.
# - `postgresql_tablespace` places the index in an existing PostgreSQL tablespace.
# - `postgresql_with` passes storage parameters supported by the selected index access method. Check that your Bingo/PostgreSQL version supports each parameter.
# - `info` stores application metadata on the SQLAlchemy object and does not change the generated SQL. Other standard options, such as `unique`, are also forwarded, but the underlying `bingo_idx` access method must support the requested feature.
#
# For example, this illustrative index covers only NSAID molecules, is built concurrently, and is stored in an existing tablespace named `fast_indexes`:
#
# ```python
# index.BingoMolIndex(
#     "ix_molecules_nsaid_mol",
#     "mol",
#     postgresql_where=text("is_nsaid IS TRUE"),
#     postgresql_concurrently=True,
#     postgresql_tablespace="fast_indexes",
#     info={"purpose": "NSAID structure searches"},
# )
# ```
#
# For the `Molecule` table above, SQLAlchemy generates the following `CREATE INDEX` statement (the `info` value is Python-only metadata):
#
# ```sql
# CREATE INDEX CONCURRENTLY ix_molecules_nsaid_mol
# ON molalchemy_tutorial_molecules
# USING bingo_idx (mol bingo.molecule)
# TABLESPACE fast_indexes
# WHERE is_nsaid IS TRUE;
# ```
#
# `BingoMolIndex` always keeps `postgresql_using="bingo_idx"` and the required `bingo.molecule` operator class. The binary-molecule and reaction index classes similarly select their required Bingo operator classes, so these two settings cannot be overridden. See SQLAlchemy's [PostgreSQL-specific index options](https://docs.sqlalchemy.org/en/20/dialects/postgresql.html#postgresql-specific-index-options) for the complete option reference.

# %% [markdown]
# ## Adding Sample Molecular Data
#
# Let's insert some sample pharmaceutical compounds with their SMILES representations. Our dataset includes:
#
# - **Aspirin**: A common NSAID (non-steroidal anti-inflammatory drug)
# - **Loratadine**: An antihistamine for allergy treatment
# - **Rofecoxib**: A withdrawn COX-2 inhibitor NSAID
# - **Captopril**: An ACE inhibitor for treating hypertension
# - **Thalidomide**: A medication with a complex history, now used for certain cancers
#
# Each molecule is stored with its SMILES string, name, and NSAID classification.

# %%
data = [
    {"name": "Aspirin", "mol": "CC(=O)OC1=CC=CC=C1C(=O)O", "is_nsaid": True},
    {
        "name": "Loratadine",
        "mol": "O=C(OCC)N4CC/C(=C2/c1ccc(Cl)cc1CCc3cccnc23)CC4",
        "is_nsaid": False,
    },
    {
        "name": "Rofecoxib",
        "mol": "O=C2OC\\C(=C2\\c1ccccc1)c3ccc(cc3)S(C)(=O)=O",
        "is_nsaid": True,
    },
    {"name": "Captopril", "mol": "C[C@H](CS)C(=O)N1CCC[C@H]1C(=O)O", "is_nsaid": False},
    {
        "name": "Talidomide",
        "mol": "O=C1c2ccccc2C(=O)N1C3CCC(=O)NC3=O",
        "is_nsaid": False,
    },
]

session = SessionLocal()
mols = [Molecule(**d) for d in data]
session.add_all(mols)
session.commit()
# run vacuum to fix issue bingo >= 1.36.0

# %%
autocommit_engine = eng.execution_options(isolation_level="AUTOCOMMIT")
with SessionLocal(bind=autocommit_engine) as session:
    session.execute(text("VACUUM molalchemy_tutorial_molecules"))

# %% [markdown]
# ## Basic Chemical Queries
#
# Now let's explore different ways to query our molecular data:
#
# ### 1. Standard Database Queries
# First, a simple query using regular SQLAlchemy operations to find non-NSAID molecules:

# %%
# simple query to get all non-nsaid molecules
session.execute(select(Molecule).where(Molecule.is_nsaid == False)).all()
# Out:
# [(Molecule(id=2, name='Loratadine', mol='O=C(OCC)N4CC/C(=C2/c1ccc(Cl)cc1CCc3cccnc23)CC4', is_nsaid=False),),
#  (Molecule(id=4, name='Captopril', mol='C[C@H](CS)C(=O)N1CCC[C@H]1C(=O)O', is_nsaid=False),),
#  (Molecule(id=5, name='Talidomide', mol='O=C1c2ccccc2C(=O)N1C3CCC(=O)NC3=O', is_nsaid=False),)]

# %% [markdown]
# ### 2. Exact Molecular Structure Matching
# Use `molalchemy.bingo.functions.mol_equals()` to find molecules that exactly match a given structure. Bingo's native `==` and `!=` operators compare stored text or compact binary data, not chemical identity, so equivalent SMILES such as `CCO` and `OCC` compare different. Use `mol_equals()` or the explicit `.equals()` comparator for chemical equality. This differs from RDKit molecule columns, where native `==` and explicit `.equals()` are both chemically aware:

# %%
session.execute(
    select(Molecule).where(
        functions.mol_equals(Molecule.mol, "CC(=O)OC1=CC=CC=C1C(=O)O")
    )
).all()
# Out:
# [(Molecule(id=1, name='Aspirin', mol='CC(=O)OC1=CC=CC=C1C(=O)O', is_nsaid=True),)]

# %% [markdown]
# The same function is available as a part of mol comparator, without the `mol_` prefix:

# %%
session.execute(
    select(Molecule).where(Molecule.mol.equals("CC(=O)OC1=CC=CC=C1C(=O)O"))
).all()
# Out:
# [(Molecule(id=1, name='Aspirin', mol='CC(=O)OC1=CC=CC=C1C(=O)O', is_nsaid=True),)]

# %% [markdown]
# ### 3. Substructure Searches
# Find molecules containing a specific substructure. Here we search for molecules containing sulfur (`S`):

# %%
session.execute(
    select(Molecule).where(functions.mol_has_substructure(Molecule.mol, "S"))
).all()
# Out:
# [(Molecule(id=3, name='Rofecoxib', mol='O=C2OC\\C(=C2\\c1ccccc1)c3ccc(cc3)S(C)(=O)=O', is_nsaid=True),),
#  (Molecule(id=4, name='Captopril', mol='C[C@H](CS)C(=O)N1CCC[C@H]1C(=O)O', is_nsaid=False),)]

# %% [markdown]
# The same function is available as a part of mol comparator, without the `mol_` prefix:

# %%
session.execute(select(Molecule).where(Molecule.mol.has_substructure("S"))).all()
# Out:
# [(Molecule(id=3, name='Rofecoxib', mol='O=C2OC\\C(=C2\\c1ccccc1)c3ccc(cc3)S(C)(=O)=O', is_nsaid=True),),
#  (Molecule(id=4, name='Captopril', mol='C[C@H](CS)C(=O)N1CCC[C@H]1C(=O)O', is_nsaid=False),)]

# %% [markdown]
# Use `mol_has_smarts()` when the query is a SMARTS pattern rather than a molecule structure. Bingo 1.40 can route SMARTS predicates on indexed molecule columns through a broken index path, so this example searches the molecule SMILES expression to keep the tutorial portable:

# %%
session.execute(
    select(Molecule).where(functions.mol_has_smarts(Molecule.mol, "[#16]"))
).all()
# Out:
# [(Molecule(id=3, name='Rofecoxib', mol='O=C2OC\\C(=C2\\c1ccccc1)c3ccc(cc3)S(C)(=O)=O', is_nsaid=True),),
#  (Molecule(id=4, name='Captopril', mol='C[C@H](CS)C(=O)N1CCC[C@H]1C(=O)O', is_nsaid=False),)]

# %%
session.execute(
    select(Molecule).where(functions.mol_has_smarts(Molecule.mol, "[#16]"))
).all()
# Out:
# [(Molecule(id=3, name='Rofecoxib', mol='O=C2OC\\C(=C2\\c1ccccc1)c3ccc(cc3)S(C)(=O)=O', is_nsaid=True),),
#  (Molecule(id=4, name='Captopril', mol='C[C@H](CS)C(=O)N1CCC[C@H]1C(=O)O', is_nsaid=False),)]

# %%
from sqlalchemy.dialects import postgresql

q = select(Molecule).where(functions.mol_has_smarts(Molecule.mol, "[#16]"))
# complie to raw SQL to see the parameters being passed to the Bingo functions
print(
    str(
        q.compile(
            {}, dialect=postgresql.dialect(), compile_kwargs={"literal_binds": True}
        )
    )
)
# Out:
# SELECT molalchemy_tutorial_molecules.id, molalchemy_tutorial_molecules.name, molalchemy_tutorial_molecules.mol, molalchemy_tutorial_molecules.is_nsaid
# FROM molalchemy_tutorial_molecules
# WHERE molalchemy_tutorial_molecules.mol @ CAST(('[#16]', '') AS bingo.smarts)

# %% [markdown]
# ## Reaction Searches
#
# Standalone Bingo reaction helpers use the `rxn_` prefix. The matching comparator methods are still available directly on `BingoReaction` columns.

# %%
class Reaction(Base):
    __tablename__ = "molalchemy_tutorial_reactions"
    __table_args__ = (
        index.BingoRxnIndex("molalchemy_tutorial_bingo_orm_rxn_idx", "rxn"),
    )
    id: Mapped[int] = mapped_column(
        Integer, primary_key=True, autoincrement=True, init=False
    )
    name: Mapped[str] = mapped_column(String(100), unique=True)
    rxn: Mapped[str] = mapped_column(types.BingoReaction)


Reaction.__table__.drop(eng, checkfirst=True)
Reaction.__table__.create(eng, checkfirst=False)
session.add_all(
    [
        Reaction(name="ethanol oxidation", rxn="CCO>>CC=O"),
        Reaction(name="alkene hydrogenation", rxn="C=C>>CC"),
    ]
)
session.commit()

# %%
session.execute(
    select(Reaction).where(functions.rxn_has_substructure(Reaction.rxn, "CCO>>CC=O"))
).all()

session.execute(
    select(Reaction).where(functions.rxn_has_smarts(Reaction.rxn, "[C:1]>>[C:1][O]"))
).all()

session.execute(
    select(Reaction).where(functions.rxn_equals(Reaction.rxn, "C=C>>CC"))
).all()
# Out:
# [(Reaction(id=2, name='alkene hydrogenation', rxn='C=C>>CC'),)]

# %% [markdown]
# ## Similarity Searching
#
# In Bingo case we don't need to create a fingerprint column, we can search directly on the `BingoMol` column instead.

# %%
class Base(MappedAsDataclass, DeclarativeBase):
    pass


class MoleculeFP(Base):
    __tablename__ = "molalchemy_tutorial_molecules_fp"
    __table_args__ = (
        index.BingoMolIndex("molalchemy_tutorial_bingo_orm_mol_gist_idx_2", "mol"),
    )
    id: Mapped[int] = mapped_column(
        Integer, primary_key=True, autoincrement=True, init=False
    )
    name: Mapped[str] = mapped_column(String(100), unique=True)
    mol: Mapped[bytes] = mapped_column(types.BingoMol)
    is_nsaid: Mapped[bool] = mapped_column(Boolean, default=False)


MoleculeFP.__table__.drop(eng, checkfirst=True)
MoleculeFP.__table__.create(eng, checkfirst=True)

# %% [markdown]
# ### Inserting Data with Automatic Fingerprint Generation
#
# When we insert molecules into this enhanced model, the fingerprints are automatically computed:

# %%
session = SessionLocal()
session.add_all([MoleculeFP(**d) for d in data])
session.commit()

# %% [markdown]
# ### Similarity Searching with Tanimoto Coefficient
#
# Now we can perform similarity searches using the Tanimoto coefficient, which compares molecular fingerprints.
#
# In this example, we:
# 1. Generate a fingerprint for a query molecule (Desloratadine's SMILES - active metabolite of Loratadine)
# 2. Calculate Tanimoto similarity between the query and all stored fingerprints
# 3. Rank results by similarity score in descending order

# %%
target_smi = "Clc4cc2c(C(c1ncccc1CC2)=C3CCNCC3)cc4"
similarity_expr = functions.getsimilarity(MoleculeFP.mol, target_smi).label(
    "similarity"
)
final_query = select(similarity_expr, MoleculeFP).order_by(similarity_expr.desc())
session.execute(final_query).all()
# Out:
# [(0.8, MoleculeFP(id=2, name='Loratadine', mol='O=C(OCC)N4CC/C(=C2/c1ccc(Cl)cc1CCc3cccnc23)CC4', is_nsaid=False)),
#  (0.28846154, MoleculeFP(id=5, name='Talidomide', mol='O=C1c2ccccc2C(=O)N1C3CCC(=O)NC3=O', is_nsaid=False)),
#  (0.24369748, MoleculeFP(id=3, name='Rofecoxib', mol='O=C2OC\\C(=C2\\c1ccccc1)c3ccc(cc3)S(C)(=O)=O', is_nsaid=True)),
#  (0.17821783, MoleculeFP(id=1, name='Aspirin', mol='CC(=O)OC1=CC=CC=C1C(=O)O', is_nsaid=True)),
#  (0.17117117, MoleculeFP(id=4, name='Captopril', mol='C[C@H](CS)C(=O)N1CCC[C@H]1C(=O)O', is_nsaid=False))]

# %% [markdown]
# ### Similarity Predicate and Score APIs
#
# Bingo molecule columns provide two complementary high-level operations:
#
# - `.similarity_score()` and `functions.mol_similarity_score()` return a numeric score for selecting, labeling, or ordering results.
# - `.similar_to()` and `functions.mol_similar_to()` return a Boolean predicate bounded by `minimum` and `maximum`. Either bound can be `None`.
#
# The cartridge-level `functions.getsimilarity()` function used above remains available. `functions.mol_similarity()` is the backward-compatible predicate spelling with the older `bottom` and `top` parameter names. All of these APIs operate directly on `BingoMol`; no explicit fingerprint column is required.

# %%
score_expr = MoleculeFP.mol.similarity_score(target_smi).label("similarity")
score_function = functions.mol_similarity_score(MoleculeFP.mol, target_smi)

bounded_query = select(MoleculeFP).where(
    MoleculeFP.mol.similar_to(target_smi, minimum=0.7, maximum=1.0)
)
bounded_function_query = select(MoleculeFP).where(
    functions.mol_similar_to(
        MoleculeFP.mol, target_smi, minimum=0.7, maximum=1.0
    )
)

session.execute(bounded_query).scalars().all()
# Out:
# [MoleculeFP(id=2, name='Loratadine', mol='O=C(OCC)N4CC/C(=C2/c1ccc(Cl)cc1CCc3cccnc23)CC4', is_nsaid=False)]

# %% [markdown]
# ### Inspecting the Generated SQL
#
# We can examine the actual SQL query that SQLAlchemy generates for our similarity search:

# %%
print(final_query.compile(eng, compile_kwargs={"literal_binds": True}))
# Out:
# SELECT bingo.getsimilarity(molalchemy_tutorial_molecules_fp.mol, 'Clc4cc2c(C(c1ncccc1CC2)=C3CCNCC3)cc4', 'tanimoto') AS similarity, molalchemy_tutorial_molecules_fp.id, molalchemy_tutorial_molecules_fp.name, molalchemy_tutorial_molecules_fp.mol, molalchemy_tutorial_molecules_fp.is_nsaid
# FROM molalchemy_tutorial_molecules_fp ORDER BY similarity DESC

# %% [markdown]
# ## Summary
#
# This tutorial demonstrated the key features of MolAlchemy with Bingo cartridge:
#
# 1. **Database Setup**: Connecting to PostgreSQL with Bingo extension
# 2. **Model Definition**: Creating SQLAlchemy models with chemical data types
# 3. **Data Storage**: Storing molecular structures with metadata
# 4. **Basic Queries**: Exact matching and substructure searches
# 5. **Similarity Search**: Using Tanimoto coefficients to rank molecular similarity
#
#
# ### Key Differences from RDKit
#
# TODO
#
# ### Next Steps
#
# - Explore more Bingo functions available in `molalchemy.bingo.functions`
# - Try different fingerprint types and similarity metrics
# - Implement custom molecular descriptors as computed columns
# - Scale up with larger molecular databases
# - Compare performance between Bingo and RDKit cartridges
#
# ### Additional Resources
#
# - [Bingo PostgreSQL Manual](https://lifescience.opensource.epam.com/bingo/bingo-postgres.html)
# - [SQLAlchemy Documentation](https://docs.sqlalchemy.org/)
# - [EPAM Indigo Toolkit](https://github.com/epam/Indigo)
